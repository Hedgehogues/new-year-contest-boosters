# %%
import json

from os import listdir
from os.path import isfile, join
from tqdm import tqdm
import pandas as pd
import numpy as np
import re

from sklearn.neighbors import KNeighborsClassifier

import json

from os import listdir
from os.path import isfile, join
from tqdm import tqdm
import pandas as pd
import numpy as np
import re
from yandex.get_yandex_ratings import get_items

from sklearn.neighbors import KNeighborsClassifier

import pandas as pd
import numpy as np
from math import sin, cos, sqrt, atan2, radians
from tqdm import tqdm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from matplotlib.markers import MarkerStyle
from postal.parser import parse_address
from tqdm import tqdm
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from scipy.interpolate import spline
from sklearn.cluster import DBSCAN
from collections import Counter
import json



fontsize = 18
figsize = (15,10)
plot_alpha = 0.3
linewidth = 4

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
def str_to_point(s):
    if s is None:
        return None
    l = s.split(' ')
    return {'long': float(l[0]), 'lat': float(l[1])}

# %%
train = pd.read_csv('data/train.csv', index_col=0)
test = pd.read_csv('data/test.csv', index_col=0)
test = test.rename(columns={'atm_group': '0-bank'})
train = train.rename(columns={'atm_group': '0-bank'})
banks = np.uint(np.sort(test['0-bank'].unique() * 10))

with open('missed_coords.json', 'r') as infile:
    missed_coords = json.load(infile)

# %%
missed_coords = [(str_to_point(item[0]), item[1], item[2], item[3]) for item in missed_coords]

# %%
test = test.rename(columns={'lat': '6-lat', 'long': '6-long'})
train = train.rename(columns={'lat': '6-lat', 'long': '6-long'})

# %% [markdown]
# # Prepare

# %%
test['0-bank'] = np.uint(test['0-bank'] * 10)
train['0-bank'] = np.uint(train['0-bank'] * 10)
columns_for_drop = ['address', 'address_rus']

# %% [markdown]
# ### Запоминаем индексы

# %%
train['is_train'] = True
test['is_train'] = False
test['index'] = test.index + 1
train['index'] = train.index + 1
train['train_index'] = train.index + 1
test['test_index'] = test.index + 1
train['test_index'] = 0
test['train_index'] = 0
train['index'] = train.index

# %% [markdown]
# ### Создаём общие данные tran-test

# %%
data_all = train.append(test, sort=False)

data_all['address_fail'] = 0
data_all.at[data_all['address_rus'].isnull(), 'address_fail'] = 1
data_all['base_target'] = data_all['target']
data_all.at[(data_all['address_fail'] == 1) & (data_all['is_train']), 'target'] = 0

data_all['address_rus'] = data_all['address_rus'].fillna('')

counts = data_all.groupby('address_rus')['id'].count().reset_index().rename(columns={'id':'the_same_address_terminals'})
data_all = pd.merge(data_all, counts, how='left', on='address_rus')
data_all.at[data_all['address_fail'] == 1, 'the_same_address_terminals'] = 0

# %%
test['0-bank'] = np.uint(test['0-bank'] * 10)
train['0-bank'] = np.uint(train['0-bank'] * 10)

# %% [markdown]
# ### Fillna for address_rus

# %%
data_all.at[data_all['address_fail'], 'address_rus'] = data_all['address_rus'].fillna("")

# %% [markdown]
# ### Fillna for lat, long

# %%
data_all.at[:, ['6-lat', '6-long']] = data_all[['6-lat', '6-long']].fillna(0)

# %% [markdown]
# ### Fill missed coords

# %%
missed_ids = [item[3] for item in missed_coords]
missed_cities = [item[2] for item in missed_coords]
missed_levels = [1 if item[1] == 'Level.HOUSE' else 0 for item in missed_coords]
missed_lats = [item[0]['lat'] if item[0] is not None else None for item in missed_coords]
missed_longs = [item[0]['long'] if item[0] is not None else None for item in missed_coords]

set_missed_ids = set(missed_ids)
missed_inds = data_all['id'].apply(lambda el: el in set_missed_ids)

# %%
data_all.at[missed_inds, '6-lat'] = missed_lats
data_all.at[missed_inds, '6-long'] = missed_longs
data_all['6-levels'] = 1
data_all.at[missed_inds, '6-levels'] = missed_levels
data_all.at[missed_inds, 'city'] = ['' if city is None else city.lower() for city in missed_cities]
data_all['address_fail'] = 0
data_all['address_fail'] = data_all['6-lat'].isnull()
data_all.at[:, ['6-lat', '6-long']] = data_all[['6-lat', '6-long']].fillna(0)

# %%
data_all['0-bank_base'] = data_all['0-bank']
data_all = pd.get_dummies(data_all, columns=['0-bank'], prefix='0-bank')

# %% [markdown]
# ### Детекция городов

# %%
def custom_parse_address(row):
    if len(row) == 0:
        return 'NULL'
    d = dict([(item[1], item[0]) for item in parse_address(row)])
    city = ''
    if 'city' in d:
        city = d['city']
    return city

data_all['city-temp'] = data_all['address_rus'].apply(custom_parse_address)

# %%
data_all.loc[missed_inds, 'city-temp'] = data_all[missed_inds]['city']
data_all['city'] = data_all['city-temp']
data_all['city'] = list(map(lambda x: x.replace('-', ' ').lower().replace('город ', '').replace(' город', '').replace('ё', 'e'), data_all['city']))
del data_all['city-temp']

# %%
# Не задетектились

d = {
    60: 'ст дружба-1',
    299: 'буденновский лес',
    300: 'буденновский лес',
    4443: 'екатеринбург',
    4444: 'екатеринбург',
    4445: 'екатеринбург',
    4446: 'екатеринбург',
    8374: 'усть-илимск',
    8386: 'усть-илимск',
    4609: 'усть-илимск'
}
for k in d:
    data_all.at[k, 'city'] = d[k]
data_all.at[data_all['city'] == '', 'city'] = data_all[data_all['city'] == ''].index.astype(str)

data_all = data_all[['0-bank_base', 'address_rus', 'address', '6-lat', '6-long', 'city']]

# %%
data_all.head()
# Out:
#    0-bank_base                                        address_rus  \
# 0          320  улица А.О. Емельянова, 34, Южно-Сахалинск, Сах...
# 1          320  Комсомольская улица, 259, Южно-Сахалинск, Саха...
# 2          320  Коммунистический проспект, Южно-Сахалинск, Сах...
# 3          320  Ленинградский проспект, 76А, Москва, Россия, 1...
# 4          320  Гвардейская площадь, 2, Норильск, Красноярский...
#
#                                   address      6-lat      6-long  \
# 0  EMELYANOVA,34          Y-SAKHALINSK     46.940995  142.738319
# 1  KOMSOMOLSKAYA,259B     Y.SAKHALINSK     46.937353  142.753348
# 2  KOMMUN. PR., 32        YUZHNO SAKHAL    46.959413  142.741113
# 3  LENINGRADSKIY PR.,76A  MOSCOW           55.805827   37.515146
# 4  GVARDEYSKAYA PL., 2    NORILSK          69.343541   88.211228
#
#              city
# 0  южно сахалинск
# 1  южно сахалинск
# 2  южно сахалинск
# 3          москва
# 4        норильск

# %% [markdown]
# ### Извлечение информации о отделениях банков

# %%
def extract_time_schedule(el):
    s = 1000
    f = -1
    weekend = 0
    stop = 0
    if el['type'] == 'atm':
        s, f, weekend = 0, 24, 1
    for sch in ['schedule_general', 'schedule_private_person', 'schedule_entities', 'schedule_vip']:
        stop |= el[sch].find('перерыв') > 0
        s = min([s] + list(map(int, re.findall('\d', el[sch]))))
        f = max([f] + list(map(int, re.findall('\d', el[sch]))))
        if el[sch].find('сб') > -1 or el[sch].find('вс') > -1:
            weekend = 1
    return s, f, weekend, stop

def extract_desc(desc, data, name, debug=0):
    dots = []
    for ind, item in enumerate(desc):
        if item['longitude'] is not None and item['latitude'] is not None and len(item['longitude']) != 0 and len(item['latitude']) != 0:
            dots.append([item['longitude'], item['latitude']])
        else:
            dots.append([1000000, 10000000])

    knc = KNeighborsClassifier()
    knc.fit(X=dots , y=np.ones(len(dots)))

    ds, i_s = knc.kneighbors(X=list(zip(data['6-long'].values, data['6-lat'].values)), n_neighbors=5)

    matched = []
    for ind, item in enumerate(zip(ds, i_s)):
        d, i = item
        if debug == 0:
            print('--------------------------------------------', ind)
            print(d)
            print('BANKI.RU:', desc[i[0]]['longitude'], desc[i[0]]['latitude'], desc[i[0]]['address'])
            print('ADDRESS_RUS:', data['6-long'].iloc[ind], data['6-lat'].iloc[ind], data['address_rus'].iloc[ind])
            print('ADDRESS:', data['address'].iloc[ind])
        args = {
            'active': 0,
            'type': '',
            'time_schedule_s': 0,
            'time_schedule_f': 0,
            'time_schedule_week': 0,
            'time_schedule_stop': 0,
            'metro_name': 0,
            'without_weekend': 0,
            'is_round_the_clock': 0,
            'is_works_as_shop': 0,
            'is_at_closed_place': 0,
            'actual': 0,
            'comment_to_address': '',
            'bank_name': name,
            'index': data.index[ind],
        }
        if d[0] < 5e-3:
            el = desc[i[0]]
            a = extract_time_schedule(el)
            args = {
                'active': int(el['active']),
                'type': el['type'],
                'time_schedule_s': a[0],
                'time_schedule_f': a[1],
                'time_schedule_week': a[2],
                'time_schedule_stop': a[3],
                'metro_name': int(len(el['metro_name']) != 0),
                'without_weekend': el['without_weekend'],
                'is_round_the_clock': int(el['is_round_the_clock']),
                'is_works_as_shop': int(el['is_works_as_shop']),
                'is_at_closed_place': int(el['is_at_closed_place']),
                'actual': 1,
                'comment_to_address': el['comment_to_address'],
                'bank_name': name,
                'index': data.index[ind],
            }
            matched.append(args)
            
            if debug == 1:
                print('--------------------------------------------', ind)
                print(d)
                print('BANKI.RU:', desc[i[0]]['longitude'], desc[i[0]]['latitude'], desc[i[0]]['address'])
                print('ADDRESS_RUS:', data['6-long'].iloc[ind], data['6-lat'].iloc[ind], data['address_rus'].iloc[ind])
                print('ADDRESS:', data['address'].iloc[ind])
            continue
        elif debug == 2:
            print('--------------------------------------------', ind)
            print(d)
            print('BANKI.RU:', desc[i[0]]['longitude'], desc[i[0]]['latitude'], desc[i[0]]['address'])
            print('ADDRESS_RUS:', data['6-long'].iloc[ind], data['6-lat'].iloc[ind], data['address_rus'].iloc[ind])
            print('ADDRESS:', data['address'].iloc[ind])
        matched.append(args)
    return matched

# %%
path = 'banki.ru/desc/'
onlyfiles = sorted([f for f in listdir(path) if isfile(join(path, f))])
all_descs = []
for f in tqdm(onlyfiles):
    fd = open(path + f)
    all_descs += json.load(fd)
    fd.close()
# Out:
# 100%|██████████| 280/280 [00:02<00:00, 119.12it/s]

# %%
banks = {
    'Росбанк': 80830,
    'Ак Барс': 10220,
    'Альфа-Банк': 19420,
    'Газпромбанк': 31855,
    'Райффайзенбанк': 320,
    'Россельхозбанк': 4965,
    'Банк Уралсиб': 54780,
}
bank_dict = {}
for item in all_descs:
    bank_dict[item['bank_name']] = item['bank_id']

# %%
bank_dict
# Out:
# {'Россельхозбанк': 4725,
#  'Сбербанк России': 322,
#  'Связь-Банк': 8572,
#  'Промсвязьбанк': 5306,
#  'Почта Банк': 194275,
#  'Ак Барс': 36119,
#  'ВТБ': 327,
#  'Совкомбанк': 76620,
#  'Банк «ФК Открытие»': 690,
#  'Газпромбанк': 2764,
#  'Росбанк': 3697,
#  'Банк Финсервис': 17111,
#  'Прио-Внешторгбанк': 191189,
#  'Россия': 68683,
#  'Восточный Банк': 193284,
#  'Энерготрансбанк': 193407,
#  'Азиатско-Тихоокеанский Банк': 192833,
#  'Пойдем!': 192701,
#  'Кубань Кредит': 191174,
#  'Всероссийский Банк Развития Регионов': 16995,
#  'Московский Индустриальный Банк': 8594,
#  'Альфа-Банк': 325,
#  'Газэнергобанк': 193300,
#  'Липецккомбанк': 191013,
#  'Центр-инвест': 124449,
#  'Дон-Тексбанк': 131240,
#  'Крайинвестбанк': 191118,
#  'Венец': 195188,
#  'Камский Коммерческий Банк': 193364,
#  'Русфинанс Банк': 176859,
#  'Хоум Кредит Банк': 6764,
#  'СМП Банк': 17200,
#  'Кредит Европа Банк': 41643,
#  'Райффайзенбанк': 4389,
#  'Уральский Банк Реконструкции и Развития': 95970,
#  'Банк «Возрождение»': 6877,
#  'Московский Кредитный Банк': 7292,
#  'Саровбизнесбанк': 79617,
#  'Челиндбанк': 191044,
#  'Челябинвестбанк': 191059,
#  'Инвестторгбанк': 10275,
#  'Ассоциация': 83536,
#  'Банк Уралсиб': 63520,
#  'Хлынов': 192862,
#  'Урал ФД': 191070,
#  'Курскпромбанк': 191131,
#  'Приморье': 191082,
#  'Ижкомбанк': 193992,
#  'Ренессанс Кредит': 17266,
#  'Росгосстрах Банк': 8362,
#  'Русский Стандарт': 351,
#  'Ставропольпромстройбанк': 191170,
#  'Тексбанк': 189359,
#  'Тинькофф Банк': 195706,
#  'Фора-Банк': 80493,
#  'ЮниКредит Банк': 4045,
#  'Юнистрим': 191166,
#  'Углеметбанк': 191125,
#  'Юг-Инвестбанк': 162995,
#  'ОТП Банк': 16196,
#  'НИКО-Банк': 189283,
#  'Оренбург': 191180,
#  'Форштадт': 191137,
#  'Абсолют Банк': 9259,
#  'Авангард': 5919,
#  'Левобережный': 191120,
#  'Акцепт': 192866,
#  'БайкалИнвестБанк': 192890,
#  'Бинбанк': 960,
#  'Йошкар-Ола': 190361,
#  'Крокус-Банк': 194017,
#  'Транскапиталбанк': 11518,
#  'Генбанк': 12453,
#  'РНКБ': 13011,
#  'Черноморский банк развития и реконструкции': 293131,
#  'ВУЗ-Банк': 99562,
#  'СКБ-Банк': 96003,
#  'Енисейский Объединенный Банк': 68886,
#  'Запсибкомбанк': 190997,
#  'Банк Зенит': 863,
#  'Банк Реалист (бывш. МПБ)': 14850,
#  'Московский Областной Банк': 195237,
#  'Фондсервисбанк': 13120,
#  'Геобанк': 188959,
#  'Финанс Бизнес Банк': 191139,
#  'Севергазбанк': 191048,
#  'Тольяттихимбанк': 191101,
#  'Солид Банк': 189187,
#  'Белгородсоцбанк': 192798,
#  'Славия': 76618,
#  'Сургутнефтегазбанк': 190985,
#  'Экси-Банк': 68777,
#  'Алмазэргиэнбанк': 101146,
#  'Банк «Санкт-Петербург»': 68665,
#  'Норвик Банк': 193292,
#  'Евроальянс': 192869,
#  'ЦентроКредит': 6208,
#  'Эксперт Банк': 196987,
#  'Дальневосточный Банк': 191107,
#  'Примсоцбанк': 191203,
#  'НБД-Банк': 79625,
#  'Кольцо Урала': 100655,
#  'Кубаньторгбанк': 195684,
#  'Банк Агора': 190450,
#  'ДельтаКредит': 17061,
#  'Снежинский': 191164,
#  'Земский Банк': 193319,
#  'СДМ-Банк': 37473,
#  'Холдинвестбанк': 197014,
#  'Русь': 192762,
#  'Вкабанк': 192735,
#  'Байкалкредобанк': 194350,
#  'ГринКомБанк': 190974,
#  'Костромаселькомбанк': 195245,
#  'ТЭМБР-Банк': 173689,
#  'Экономбанк': 191738,
#  'Межрегиональный промышленно-строительный банк': 191904,
#  'ББР Банк': 12092,
#  'ФорБанк': 193978,
#  'МТС Банк': 6055,
#  'Берейт': 3562831,
#  'Братский АНКБ': 189223,
#  'БКС Банк': 190303,
#  'Калуга': 194599,
#  'Кошелев-Банк': 79904,
#  'Акибанк': 191079,
#  'Банк ДОМ.РФ': 2237,
#  'Банк Интеза': 16120,
#  'Банк «Фридом Финанс»': 189914,
#  'БыстроБанк': 191928,
#  'Локо-Банк': 9183,
#  'Нейва': 105778,
#  'Элита': 196653,
#  'Агропромкредит': 10316,
#  'Девон-Кредит': 191046,
#  'Кредитинвест': 190760,
#  'Заречье': 192803,
#  'Ланта-Банк': 15227,
#  'Вологжанин': 190143,
#  'Зенит Сочи': 189967,
#  'Кузнецкий': 194898,
#  'Нефтепромбанк': 37491,
#  'Хакасский Муниципальный Банк': 190481,
#  'Химик': 91302,
#  'Кузнецкбизнесбанк': 191213,
#  'Финам Банк': 114461,
#  'Экспобанк': 2631,
#  'Московский Нефтехимический Банк': 187046,
#  'Автоградбанк': 192880,
#  'Народный Инвестиционный Банк': 191354,
#  'Невский Банк': 68794,
#  'Новикомбанк': 9789,
#  'Радиотехбанк': 83532,
#  'Ситибанк': 8368,
#  'Солидарность (Самара)': 191007,
#  'Союз': 5348,
#  'Спутник': 195578,
#  'Тимер Банк': 192887,
#  'Промтрансбанк': 194000,
#  'Роскомснаббанк (бывш. Башкомснаббанк)': 189303,
#  'Банк БКФ': 17286,
#  'Донкомбанк': 125722,
#  'Земкомбанк': 190289,
#  'Ростфинанс': 191196,
#  'Сельмашбанк': 125705,
#  'Таганрогбанк': 131265,
#  'ЦМРБанк': 8843166,
#  'Чувашкредитпромбанк': 193404,
#  'Аверс': 193185,
#  'Банк Казани': 192884,
#  'Татсоцбанк': 189909,
#  'Энергобанк': 192841,
#  'Индустриальный Сберегательный Банк': 122250,
#  'Центрально-Азиатский': 191367,
#  'Новобанк': 193416,
#  'Кемсоцинбанк': 197020,
#  'Мегаполис': 194290,
#  'Металлинвестбанк': 9011,
#  'Руснарбанк': 194209,
#  'Александровский': 68768,
#  'Таврический': 68687,
#  'Томскпромстройбанк': 191760,
#  'Проинвестбанк': 190192,
#  'Меткомбанк (Каменск-Уральский)': 108146,
#  'Руна-Банк': 196713,
#  'Первоуральскбанк': 100671,
#  'Кранбанк': 195615,
#  'Социнвестбанк': 191084,
#  'Нацинвестпромбанк': 17164,
#  'Национальный Стандарт — Южный филиал': 10633986,
#  'Алтайкапиталбанк': 193968,
#  'Сибсоцбанк': 192839,
#  'Морской Банк': 76555,
#  'Примтеркомбанк': 189960,
#  'Роял Кредит Банк': 190227,
#  'Актив Банк': 193402,
#  'КС Банк': 192823,
#  'Далена Банк': 195532,
#  'Майский': 189385,
#  'Дом-Банк': 189945,
#  'Автоторгбанк': 195654,
#  'Космос': 195551,
#  'Тамбовкредитпромбанк': 194277,
#  'Трансстройбанк': 14480,
#  'Банк Жилищного Финансирования': 619,
#  'Евразийский Банк': 195700,
#  'ИТ Банк': 138399,
#  'Плюс Банк': 191157,
#  'Промышленно-Финансовое Сотрудничество': 194279,
#  'Бэнк оф Чайна': 187059,
#  'Алеф-Банк': 9954,
#  'Ноосфера': 196704,
#  'Агророс': 196721,
#  'Банк АВБ': 191066,
#  'РТС-Банк': 196700,
#  'Камчаткомагропромбанк': 192860,
#  'Муниципальный Камчатпрофитбанк': 191915,
#  'Русский Банк Сбережений': 191957,
#  'Профессионал Банк (бывш. Наш Дом)': 189900,
#  'Объединенный Резервный Банк': 195509,
#  'Объединенный Капитал': 68806,
#  'Платина': 11498,
#  'Кредит Урал Банк': 191036,
#  'БСТ-Банк': 189235,
#  'Сервис Резерв': 77481,
#  'Континенталь': 188774,
#  'МВС Банк': 190511,
#  'Невастройинвест': 189362,
#  'РБА': 191982,
#  'Азия-Инвест Банк': 188085,
#  'АйСиБиСи Банк': 384111,
#  'Акрополь': 187472,
#  'Альба Альянс': 17091,
#  'Альтернатива': 241208,
#  'Америкэн Экспресс Банк': 389146,
#  'Апабанк': 190999,
#  'Аресбанк': 17216,
#  'Аспект': 17268,
#  'Банк Глобус': 191374,
#  'Банк Кредит Свисс': 8408,
#  'Банк Оранжевый': 191747,
#  'Банк ПСА Финанс Рус': 503943,
#  'Банк Раунд': 187062,
#  'Банк РМП': 189296,
#  'Банк РСИ': 191376,
#  'Банк Сберегательно-кредитного сервиса': 16960,
#  'Банкхаус Эрбе': 17282,
#  'Бест Эффортс Банк': 17280,
#  'Бинбанк Диджитал': 10754,
#  'БКС Премьер': 10500345,
#  'БМ-Банк': 3425,
#  'БМВ Банк': 504553,
#  'БНП Париба Банк': 17151,
#  'Веста': 188525,
#  'Внешфинбанк': 188824,
#  'ВРБ': 1610653,
#  'ВЭБ': 682166,
#  'Гарант-Инвест': 76602,
#  'Голдман Сакс Банк': 710591,
#  'Гута-Банк': 193988,
#  'Денизбанк Москва': 152985,
#  'Держава': 9751,
#  'Джей энд Ти Банк': 188680,
#  'Дж. П.\xa0Морган Банк': 9700,
#  'Дойче Банк': 8487,
#  'ДОМ.РФ': 10247510,
#  'Евроазиатский Инвестиционный Банк': 129934,
#  'Еврокапитал-Альянс': 190348,
#  'Еврофинанс Моснарбанк': 4374,
#  'Живаго Банк': 189923,
#  'Жилкредит': 194610,
#  'Жилстройбанк': 189984,
#  'Заубер Банк': 197029,
#  'Зираат Банк': 194288,
#  'Иваново': 195219,
#  'ИК Банк': 189266,
#  'Инбанк': 188229,
#  'ИНГ Банк': 8548,
#  'Интерпрогрессбанк': 77487,
#  'Интерпромбанк': 15760,
#  'ИРС': 189309,
#  'Ишбанк': 80479,
#  'Капитал': 17214,
#  'Киви Банк': 189185,
#  'Коммерцбанк (Евразия)': 9179,
#  'Коммерческий Индо Банк': 17237,
#  'Консервативный Коммерческий Банк': 190708,
#  'Креди Агриколь КИБ': 68669,
#  'Кредпромбанк': 197038,
#  'Кремлевский': 195626,
#  'Кросна-Банк': 188678,
#  'Кузнецкий Мост': 17244,
#  'КЭБ ЭйчЭнБи Банк': 6720904,
#  'Лэнд-Банк': 191135,
#  'Максима': 137404,
#  'МБА-Москва': 77517,
#  'Международный Коммерческий Банк': 195528,
#  'Международный Расчетный Банк': 193482,
#  'Международный Финансовый Клуб': 14400,
#  'Мерседес-Бенц Банк Рус': 366265,
#  'Металлург': 194613,
#  'Мидзухо Банк': 10253,
#  'Мир Бизнес Банк': 152898,
#  'Модульбанк': 195649,
#  'Морган Стэнли Банк': 111734,
#  'Москва-Сити': 77511,
#  'Московский Коммерческий Банк': 77509,
#  'Нэклис-Банк': 189965,
#  'Севастопольский Морской Банк': 293136,
#  'Московское Ипотечное Агентство': 17147,
#  'Москоммерцбанк': 17139,
#  'МС Банк Рус': 194578,
#  'МСП Банк': 4309,
#  'МТИ Банк': 195975,
#  'Народный Банк': 190355,
#  'Народный Банк Тувы': 196971,
#  'Народный Доверительный Банк': 194006,
#  'Натиксис Банк': 17276,
#  'Национальная Факторинговая Компания': 17135,
#  'Национальный Банк Взаимного Кредита': 173345,
#  'Национальный Банк Сбережений': 195635,
#  'Национальный Банк «Траст»': 68195,
#  'Национальный Резервный Банк': 4305,
#  'Национальный Стандарт': 16903,
#  'НК Банк': 11830,
#  'Новый Век': 194873,
#  'Новый Московский Банк': 189305,
#  'НОКССбанк': 193374,
#  'Нордеа Банк': 7491,
#  'НС Банк': 12374,
#  'Оней Банк': 4669810,
#  'Оргбанк': 189254,
#  'Первый Инвестиционный Банк (бывш. Алма-Банк)': 187077,
#  'Первый Клиентский Банк': 189483,
#  'Пересвет': 16957,
#  'Петербургский Социальный Коммерческий Банк': 68753,
#  'Прайм Финанс': 68796,
#  'Прокоммерцбанк': 189209,
#  'Проминвестбанк': 9764,
#  'Промсельхозбанк': 196696,
#  'Развитие-Столица': 4272,
#  'РАМ Банк': 464028,
#  'Рента-Банк': 195642,
#  'РЕСО Кредит': 76624,
#  'Республиканский Кредитный Альянс': 189490,
#  'Ресурс-Траст': 194255,
#  'РН Банк': 190987,
#  'Росбизнесбанк': 189860,
#  'Росдорбанк': 17212,
#  'Российская Финансовая Корпорация': 191004,
#  'Россита-Банк': 194030,
#  'Росэксимбанк': 8814,
#  'РусьРегионБанк': 195198,
#  'Русьуниверсалбанк': 8534,
#  'РФИ Банк': 189301,
#  'Северный Народный Банк': 191932,
#  'Сетелем Банк': 77476,
#  'Синко-Банк': 190363,
#  'Система': 17270,
#  'Славянский Кредит': 13136,
#  'Собинбанк': 4427,
#  'Современные Стандарты Бизнеса': 188149,
#  'Соколовский': 189269,
#  'Социум-Банк': 188469,
#  'Торжок (бывш. Торжокуниверсалбанк)': 195613,
#  'Спецстройбанк': 194002,
#  'Стандарт-Кредит': 188813,
#  'Столичный Кредит': 77489,
#  'Сумитомо Мицуи': 1275844,
#  'Тендер-Банк': 194215,
#  'Тойота Банк': 240276,
#  'Тройка-Д Банк': 17208,
#  'Унифондбанк': 189917,
#  'Ури Банк': 421572,
#  'Фольксваген Банк Рус': 2087253,
#  'Форштадт — Московский офис': 10670251,
#  'Чайна Констракшн': 4671850,
#  'Чайнасельхозбанк': 7207949,
#  'Эйч-Эс-Би-Си Банк (HSBC)': 17155,
#  'Эко-Инвест': 196642,
#  'Эм-Ю-Эф-Джи Банк (Евразия)': 191159,
#  'Эс-Би-Ай Банк (бывш. ЯР-Банк)': 80455,
#  'Ю Би Эс Банк': 282697,
#  'Майкопбанк': 195704,
#  'Старооскольский Агропромбанк': 190306,
#  'Мурманский Социальный Коммерческий Банк': 188478,
#  'Уралпромбанк': 193976,
#  'Яринтербанк': 189261,
#  'Кетовский Коммерческий Банк': 194345,
#  'Долинск': 193389,
#  'Славянбанк': 194298,
#  'Горбанк': 68711,
#  'Нижневолжский Коммерческий Банк': 192872,
#  'Вятич': 194881,
#  'Крона-Банк': 195603,
#  'Почтобанк': 189319,
#  'Объединенный Банк Республики': 190325,
#  'Онего': 194877,
#  'Балтийский Банк': 59971,
#  'Балтинвестбанк': 68717,
#  'Викинг': 68751,
#  'Витабанк': 68781,
#  'Гефест': 190981,
#  'Данске Банк': 139121,
#  'Санкт-Петербургский Банк Инвестиций': 282757,
#  'Севзапинвестпромбанк': 68747,
#  'СИАБ': 68792,
#  'Сити Инвест Банк': 68773,
#  'СЭБ Банк': 68759,
#  'Энергомашбанк': 68775,
#  'АвтоКредитБанк': 197032,
#  'Алтынбанк': 195239,
#  'Экспресс-Волга': 127097,
#  'Саммит Банк': 192001,
#  'Балаково-Банк': 194563,
#  'Спиритбанк': 189229,
#  'Владбизнесбанк': 195190,
#  'ВТБ 24': 8406,
#  'Газнефтьбанк': 190178,
#  'Саратов': 193965,
#  'Екатеринбург': 98459,
#  'Вокбанк': 91282,
#  'Ермак': 192855,
#  'Приобье': 194197,
#  'Курган': 195691,
#  'Уралфинанс': 100675,
#  'Кузбассхимбанк': 196651,
#  'Тайдон': 194343,
#  'Газтрансбанк': 188785,
#  'ЮМК': 1346996,
#  'Новокиб': 196690,
#  'Пермь': 189311,
#  'Вакобанк': 195686,
#  'Великие Луки Банк': 195652,
#  'Итуруп': 193396,
#  'Прохладный': 191206,
#  'Классик Эконом Банк': 190722,
#  'Арзамас': 131248,
#  'Икано Банк': 4903519,
#  'Дружба': 191365,
#  'Стройлесбанк': 192912,
#  'ЕАТП Банк': 196018,
#  'Взаимодействие': 189981,
#  'Северстройбанк': 3698528,
#  'Первый Дортрансбанк': 196029,
#  'Нальчик': 194883}

# %%
ress = []
for i, name in enumerate(banks):
    if i != 6:
        continue
    print(name)
    descs = []
    for item in all_descs:
        if item['bank_name'] == name:
            descs.append(item)
    x = extract_desc(descs, data_all[data_all['0-bank_base'] == banks[name]], name, -1)
    print(len([1 for item in x if item['actual']]) / len(descs))
    ress += x
# Out:
# Банк Уралсиб
# 0.31985889979979026
# /home/hedgehogues/anaconda3/envs/ozon/lib/python3.6/site-packages/sklearn/utils/validation.py:558: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   FutureWarning)
# /home/hedgehogues/anaconda3/envs/ozon/lib/python3.6/site-packages/sklearn/utils/validation.py:558: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   FutureWarning)

# %%
answ = {}
for res in ress:
    answ[res['index']] = res
    
pd.concat([pd.DataFrame(answ).T, data_all], axis=1, sort=False)
